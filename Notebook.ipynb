# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/job_summary.csv
# /kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/job_skills.csv
# /kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/linkedin_job_postings.csv

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/linkedin_job_postings.csv', nrows=100000)

df.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/account-exe...
# 1  https://www.linkedin.com/jobs/view/registered-...
# 2  https://www.linkedin.com/jobs/view/restaurant-...
# 3  https://www.linkedin.com/jobs/view/independent...
# 4  https://www.linkedin.com/jobs/view/group-unit-...
#
#              last_processed_time got_summary got_ner is_being_worked  \
# 0   2024-01-21 07:12:29.00256+00           t       t               f
# 1   2024-01-21 07:39:58.88137+00           t       t               f
# 2  2024-01-21 07:40:00.251126+00           t       t               f
# 3  2024-01-21 07:40:00.308133+00           t       t               f
# 4  2024-01-19 09:45:09.215838+00           f       f               f
#
#                                            job_title  \
# 0  Account Executive - Dispensing (NorCal/Norther...
# 1                 Registered Nurse - RN Care Manager
# 2               RESTAURANT SUPERVISOR - THE FORKLIFT
# ...

# %%
df['job_title'] = df['job_title'].astype(str)

df_filtered = df[df['job_title'].str.contains('Data Analyst', case=False, na=False)]

df_filtered.shape
# Out:
# (87, 14)

# %%
df['job_title'] = df['job_title'].astype(str)

df_filtered = df[df['job_title'].str.contains('Data Analyst', case=False, na=False)]

df_filtered.shape
# Out:
# (87, 14)

# %%
print(df.columns)
# Out:
# Index(['job_link', 'last_processed_time', 'got_summary', 'got_ner',
#        'is_being_worked', 'job_title', 'company', 'job_location', 'first_seen',
#        'search_city', 'search_country', 'search_position', 'job_level',
#        'job_type'],
#       dtype='object')

# %%
skills = pd.read_csv('/kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/job_skills.csv')

merged = pd.merge(df_filtered, skills, on='job_link')

merged.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-fina...
# 1  https://www.linkedin.com/jobs/view/sr-workforc...
# 2  https://ca.linkedin.com/jobs/view/data-analyst...
# 3  https://www.linkedin.com/jobs/view/contractor-...
# 4  https://www.linkedin.com/jobs/view/vcp-design-...
#
#              last_processed_time got_summary got_ner is_being_worked  \
# 0  2024-01-21 07:14:50.991803+00           t       t               f
# 1  2024-01-21 07:15:01.601597+00           t       t               f
# 2  2024-01-21 00:27:40.684771+00           t       t               f
# 3   2024-01-21 07:16:15.96147+00           t       t               f
# 4  2024-01-21 08:02:01.538039+00           t       t               f
#
#                                            job_title                  company  \
# 0                      Senior Financial Data Analyst  The Walt Disney Company
# ...

# %%
all_skills = merged['job_skills'].str.split(',').explode()

top_skills = all_skills.value_counts().head(10)

top_skills
# Out:
# job_skills
#  SQL                   47
#  Python                39
#  Data Visualization    34
#  R                     31
#  Tableau               30
# Data Analysis          28
#  Communication         21
#  Reporting             19
#  Data Analysis         17
#  Project Management    17
# Name: count, dtype: int64

# %%
print(df_filtered.columns)
# Out:
# Index(['job_link', 'last_processed_time', 'got_summary', 'got_ner',
#        'is_being_worked', 'job_title', 'company', 'job_location', 'first_seen',
#        'search_city', 'search_country', 'search_position', 'job_level',
#        'job_type'],
#       dtype='object')

# %%
df_filtered['job_location'].value_counts().head(10)
# Out:
# job_location
# Washington, DC                       5
# New York, NY                         5
# Mountain View, CA                    4
# Cupertino, CA                        3
# Los Angeles, CA                      2
# California, United States            2
# Dallas, TX                           2
# Georgia, United States               1
# Awsworth, England, United Kingdom    1
# Waukesha, WI                         1
# Name: count, dtype: int64

# %%
all_skills = merged['job_skills'].str.split(',').explode()

top_skills = all_skills.value_counts().head(10)

top_skills
# Out:
# job_skills
#  SQL                   47
#  Python                39
#  Data Visualization    34
#  R                     31
#  Tableau               30
# Data Analysis          28
#  Communication         21
#  Reporting             19
#  Data Analysis         17
#  Project Management    17
# Name: count, dtype: int64

# %%
skills = pd.read_csv('/kaggle/input/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024/job_skills.csv')

merged = pd.merge(df_filtered, skills, on='job_link')

merged.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-fina...
# 1  https://www.linkedin.com/jobs/view/sr-workforc...
# 2  https://ca.linkedin.com/jobs/view/data-analyst...
# 3  https://www.linkedin.com/jobs/view/contractor-...
# 4  https://www.linkedin.com/jobs/view/vcp-design-...
#
#              last_processed_time got_summary got_ner is_being_worked  \
# 0  2024-01-21 07:14:50.991803+00           t       t               f
# 1  2024-01-21 07:15:01.601597+00           t       t               f
# 2  2024-01-21 00:27:40.684771+00           t       t               f
# 3   2024-01-21 07:16:15.96147+00           t       t               f
# 4  2024-01-21 08:02:01.538039+00           t       t               f
#
#                                            job_title                  company  \
# 0                      Senior Financial Data Analyst  The Walt Disney Company
# ...

# %%
merged.to_csv('final_project_data.csv', index=False)
